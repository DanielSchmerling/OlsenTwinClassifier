# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# featuretools 0.4.1 has requirement pandas>=0.23.0, but you'll have pandas 0.22.0 which is incompatible.
# datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.8 which is incompatible.
# Done.

# %%
from fastai.vision import *

# %%
path = Path('content/olsen')

# %%
folder = 'MaryKate'
file = 'marykate.csv'

path = Path('content/olsen')
dest = path/folder
dest.mkdir(parents = True, exist_ok = True)

# %%
folder = 'Ashley'
file = 'ashley.csv'

path = Path('content/olsen')
dest = path/folder
dest.mkdir(parents = True, exist_ok = True)

# %%
path.ls()
# Out:
# [PosixPath('content/olsen/MaryKate'), PosixPath('content/olsen/Ashley')]

# %%
classes = ['Ashley', 'MaryKate']

# %%
download_images('content/olsen/ashley.csv', 'content/olsen/Ashley')
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='484' class='' max='484', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [484/484 00:23<00:00]
#     </div>
# ...

# %%
download_images('content/olsen/marykate.csv', 'content/olsen/MaryKate')
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='487' class='' max='487', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [487/487 00:42<00:00]
#     </div>
# ...

# %%
verify_images('content/olsen/Ashley', delete=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='471' class='' max='471', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [471/471 00:04<00:00]
#     </div>
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:938: UserWarning: Couldn't allocate palette entry for transparency
#   "for transparency")
# int() argument must be a string, a bytes-like object or a number, not 'tuple'
# ...

# %%
verify_images('content/olsen/MaryKate', delete=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='469' class='' max='469', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [469/469 00:05<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='content/olsen/MaryKate/00000465.jpg'>
# cannot identify image file <_io.BufferedReader name='content/olsen/MaryKate/00000145.jpg'>
# cannot identify image file <_io.BufferedReader name='content/olsen/MaryKate/00000062.jpg'>
# ...

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train='.', valid_pct=0.2,
                                  ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['Ashley', 'MaryKate']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['Ashley', 'MaryKate'], 2, 419, 104)

# %% [markdown]
# TRAIN MODEL

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 102502400it [00:01, 91470200.99it/s]

# %%
learn.fit_one_cycle(6)
# Out:
# Total time: 02:08 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.924119</td>
#       <td>0.801956</td>
#       <td>0.432692</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.874726</td>
#       <td>0.678309</td>
#       <td>0.298077</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.798213</td>
#       <td>0.619167</td>
#       <td>0.240385</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.706921</td>
#       <td>0.564328</td>
#       <td>0.221154</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.624711</td>
#       <td>0.521081</td>
#       <td>0.230769</td>
#       <td>00:19</td>
#     </tr>
# ...

# %%
learn.save('olsen-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-5, 1e-3))
# Out:
# Total time: 00:39 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.391706</td>
#       <td>0.497752</td>
#       <td>0.278846</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.375280</td>
#       <td>0.558676</td>
#       <td>0.259615</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('olsen-2')

# %%
learn.load('olsen-2')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (419 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# MaryKate,MaryKate,MaryKate,MaryKate,MaryKate
# Path: content/olsen;
#
# Valid: LabelList (104 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Ashley,Ashley,MaryKate,MaryKate,MaryKate
# Path: content/olsen;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# PRODUCTION

# %%
learn.export()
